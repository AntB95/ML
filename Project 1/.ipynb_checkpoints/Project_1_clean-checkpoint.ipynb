# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from proj1_helpers import *
from implementations import *
from annexe import *
import seaborn as sns

# %%
train_set = load_csv_data('/Users/bedanian/Desktop/Machine Learning/Project 1/train.csv', sub_sample = True)
test_set = load_csv_data('/Users/bedanian/Desktop/Machine Learning/Project 1/test.csv', sub_sample = False)

# %%
# calculate the correlation matrix
x_train = train_set[1]
y_train = train_set[0]
df = pd.DataFrame(x_train)
corr = df.corr()
# plot the heatmap
plt.figure(1, figsize = (15, 10))
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns)

# %%
print(df[22].drop_duplicates())
# Out:
# 0     2.0
# 1     1.0
# 6     0.0
# 37    3.0
# Name: 22, dtype: float64

# %%
def split(data_set, indice):
    y_set = data_set[0]
    x_set = data_set[1]
    id_set = data_set[2]
    return (y_set[x_set[:,22] == indice],x_set[x_set[:,22] == indice],id_set[x_set[:,22] == indice])

def replace_mean(x_set):
    x_set[x_set == -999] = np.nan
    list_mean = x_set.mean(axis = 0)
    for i in range(0,len(list_mean)):
        x_set[np.isnan(x_set[:,i])] = list_mean[i]
    return x_set

def get_na_columns(array, threshold, value):
    na_indices = []
    for ind, row in enumerate(array.T):
        count_na = 0
        for j in range(len(row)):
            if row[j] == value:
                count_na += 1
        if (count_na/len(row)) > threshold:
            na_indices.append(ind)
    return na_indices

def standardize(x_train, x_test):
    mean = np.mean(x_train)
    norm = np.linalg.norm(x_train)
    x_train_std = (x_train - mean)/norm
    x_test_std = (x_test - mean)/norm
    return x_train_std, x_test_std

def sigmoid(x):
    return 0.5 * (1 + np.tanh(0.5*x))

def zero_to_neg(array):
    ret = np.zeros(len(array))
    for i, v in enumerate(array):
        if v == 0:
            ret[i] = -1
        else:
            ret[i] = v
    return ret

def classification(array,index):
    array[:,index] = np.log(array[:,index])
    return array

def build_poly(x, degree):
    poly = x
    for deg in range(2, degree+1):
        poly = np.concatenate((poly, np.power(x, deg)), axis = 1)
    return poly

def add_function(x):
    return np.concatenate((x,np.sin(x),np.cos(x),np.exp(x)), axis = 1)

# %%
def visualization(lambda_list, mse_train, mse_test,d):
    plt.semilogx(lambda_list, mse_train, marker=".", color='b', label='train error')
    plt.semilogx(lambda_list, mse_test, marker=".", color='r', label='test error')
    plt.xlabel("lambda")
    plt.ylabel("RMSE")
    plt.title("cross validation using polynome of degree " + str(d))
    plt.legend()
    plt.grid()

def split_data(x, y, ratio = 0.8, seed = 1):
    # set seed
    np.random.seed(seed)
    # generate random indices
    num_row = len(y)
    indices = np.random.permutation(num_row)
    index_split = int(np.floor(ratio * num_row))
    index_tr = indices[: index_split]
    index_te = indices[index_split:]
    # create split
    x_tr = x[index_tr]
    x_te = x[index_te]
    y_tr = y[index_tr]
    y_te = y[index_te]
    return x_tr, x_te, y_tr, y_te

def cross_validation(y_t,x_t,lower,upper,degree,nb,index_to_store = -999):
    (x_train, x_test, y_train, y_test) = split_data(x_t, y_t, ratio = 0.8, seed = 1)
    if index_to_store != -999:
        (store_train,x_train) = store_columns(x_train,index_to_store)
        (store_test,x_test) = store_columns(x_test,index_to_store)
    x_train = build_poly(x_train, degree)
    x_test = build_poly(x_test, degree)
    if index_to_store != -999:
        x_train = np.concatenate((x_train,store_train.reshape(len(store_train),1)), axis = 1)
        x_test = np.concatenate((x_test,store_test.reshape(len(store_test),1)), axis = 1)
    lambda_list = np.logspace(lower, upper, nb)
    rmse_train = []
    rmse_test = []
    for lbd in lambda_list:
        w = ridge_regression(y_train, x_train, lbd)[0]
        loss_train = 2*MSE(y_train, x_train, w)
        loss_test = 2*MSE(y_test, x_test, w)
        rmse_train.append(np.sqrt(loss_train))
        rmse_test.append(np.sqrt(loss_test))
    visualization(lambda_list, rmse_train, rmse_test,degree)
    return [min(rmse_test),lambda_list[np.argmin(rmse_test)]]

def store_columns(array,index):
    store = array[:,index]
    array = np.delete(array, [index] , axis = 1)
    return (store,array)

# %%
#Preprocessing
#split the datset based on column 22 value
#train
(y_train_0,x_train_0,id_train_0) = split(train_set, 0)
(y_train_1,x_train_1,id_train_1) = split(train_set, 1)
(y_train_2,x_train_2,id_train_2) = split(train_set, 2)
(y_train_3,x_train_3,id_train_3) = split(train_set, 3)
#test
(y_test_0,x_test_0,id_test_0) = split(test_set, 0)
(y_test_1,x_test_1,id_test_1) = split(test_set, 1)
(y_test_2,x_test_2,id_test_2) = split(test_set, 2)
(y_test_3,x_test_3,id_test_3) = split(test_set, 3)

#clean column of nan
nan_0 = get_na_columns(x_train_0, 0.90, -999)
x_train_0 = np.delete(x_train_0, nan_0 , axis = 1)
x_test_0 = np.delete(x_test_0, nan_0 , axis = 1)

nan_1 = get_na_columns(x_train_1, 0.90, -999)
x_train_1 = np.delete(x_train_1, nan_1 , axis = 1)
x_test_1 = np.delete(x_test_1, nan_1 , axis = 1)

nan_2 = get_na_columns(x_train_2, 0.90, -999)
x_train_2 = np.delete(x_train_2, nan_2, axis = 1)
x_test_2 = np.delete(x_test_2, nan_2, axis = 1)

nan_3 = get_na_columns(x_train_3, 0.90, -999)
x_train_3 = np.delete(x_train_3, nan_3, axis = 1)
x_test_3 = np.delete(x_test_3, nan_3, axis = 1)

#delete some columns
x_train_0 = np.delete(x_train_0, [18,19] , axis = 1)
x_train_1 = np.delete(x_train_1, [18] , axis = 1)
x_train_2 = np.delete(x_train_2, [22] , axis = 1)
x_train_3 = np.delete(x_train_3, [22] , axis = 1)

#cleaning last nan
x_train_0 = replace_mean(x_train_0)
x_train_1 = replace_mean(x_train_1)
x_train_2 = replace_mean(x_train_2)
x_train_3 = replace_mean(x_train_3)

x_test_0 = replace_mean(x_test_0)
x_test_1 = replace_mean(x_test_1)
x_test_2 = replace_mean(x_test_2)
x_test_3 = replace_mean(x_test_3)

x_train_0 = classification(x_train_0,4)
#standardize
(x_train_0,x_test_0) = standardize(x_train_0,x_test_0)
#(x_train_1,x_test_1) = standardize(x_train_1,x_test_1)
#(x_train_2,x_test_2) = standardize(x_train_2,x_test_2)
#(x_train_3,x_test_3) = standardize(x_train_3,x_test_3)

# %%
df = pd.DataFrame(x_train_0)
#df[[7,8,10,11,13,14,16]] = np.log(df[[7,8,10,11,13,14,16]])
plt.figure(1, figsize = (15, 10))
for k in range(0,df.shape[1]):
    plt.subplot(6,5,k + 1)
    df[k].hist()

# %%
np.log(df[4]).hist()

# %%
# porcessing of 0 removing 
#x_train_0 = classification(x_train_0,4)
x_train_0 = np.delete(x_train_0, [7,8,10,11,13,14,16] , axis = 1)
# processing 1
#x_train_1 = classification(x_train_1,4)
x_train_1 = np.delete(x_train_1, [7,8,10,11,13,14,16] , axis = 1)

# %%
x_train_0[:,4]
# Out:
# array([0., 1., 1., ..., 1., 0., 1.])

# %%
corr_0 = pd.DataFrame(x_train_0).corr()
corr_1 = pd.DataFrame(x_train_1).corr()
corr_2 = pd.DataFrame(x_train_2).corr()
corr_3 = pd.DataFrame(x_train_3).corr()

plt.figure(1, figsize = (15, 10))
plt.subplot(2,2,1)
sns.heatmap(corr_0, xticklabels = corr_0.columns, yticklabels = corr_0.columns)
plt.subplot(2,2,2)
sns.heatmap(corr_1, xticklabels = corr_1.columns, yticklabels = corr_1.columns)
plt.subplot(2,2,3)
sns.heatmap(corr_2, xticklabels = corr_2.columns, yticklabels = corr_2.columns)
plt.subplot(2,2,4)
sns.heatmap(corr_3, xticklabels = corr_3.columns, yticklabels = corr_3.columns)

# %%
pd.

# %%
#delete some columns
x_train_0 = np.delete(x_train_0, [18,19] , axis = 1)
x_train_1 = np.delete(x_train_1, [18] , axis = 1)
x_train_2 = np.delete(x_train_2, [] , axis = 1)
x_train_3 = np.delete(x_train_3, [] , axis = 1)

# %%
pd.DataFrame(x_train_3).head(10)
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.003169 -0.003169 -0.003169 -0.003169 -0.003169 -0.003169 -0.003169
# 1 -0.003158 -0.003169 -0.003165 -0.003171 -0.003184 -0.003168 -0.003183
# 2 -0.003157 -0.003171 -0.003167 -0.003160 -0.003184 -0.003114 -0.003184
# 3 -0.003147 -0.003184 -0.003158 -0.003171 -0.003184 -0.003150 -0.003183
# 4 -0.003146 -0.003172 -0.003163 -0.003128 -0.003184 -0.003142 -0.003184
# 5 -0.003129 -0.003158 -0.003140 -0.003138 -0.003184 -0.003116 -0.003184
# 6 -0.003135 -0.003184 -0.003168 -0.003095 -0.003182 -0.002704 -0.003186
# 7 -0.003148 -0.003181 -0.003158 -0.003171 -0.003183 -0.002907 -0.003185
# 8 -0.003146 -0.003168 -0.003164 -0.003156 -0.003183 -0.003056 -0.003185
# 9 -0.003124 -0.003154 -0.003155 -0.003079 -0.003184 -0.003034 -0.003184
#
#         7         8         9    ...       106       107       108       109  \
# 0 -0.003169 -0.003169 -0.003169  ...  0.003148  0.003148  0.003148  0.003148
# ...

# %%
#0 = [0.6851304706500787, 1e-13, 2]
#1 = [0.761819038241489, 4.2389130573387746e-12, 2]
#2 = [0.8049869465666631, 4.066478091781862e-11, 3]
#3 = [0.8406253743204616, 0.0001593693530381776, 3]
res = []
plt.figure(1, figsize = (30, 40))
for d in range(0,5):
    plt.subplot(5,5,d+1)
    res += [cross_validation(y_train_0,x_train_0,-30,1,d,1000)+[d]]
print(res[np.argmin([row[0] for row in res])])
# Out:
# [0.6876439990864266, 5.391774640387539e-06, 4]

# %%
#0 = [0.6851304706500787, 1e-13, 2]
#1 = [0.761819038241489, 4.2389130573387746e-12, 2]
#2 = [0.8049869465666631, 4.066478091781862e-11, 3]
#3 = [0.8406253743204616, 0.0001593693530381776, 3]

x_train_0 = build_poly(x_train_0, 2)
x_train_1 = build_poly(x_train_1, 2)
x_train_2 = build_poly(x_train_2, 3)
x_train_3 = build_poly(x_train_3, 3)

x_test_0 = build_poly(x_test_0, 2)
x_test_1 = build_poly(x_test_1, 2)
x_test_2 = build_poly(x_test_2, 3)
x_test_3 = build_poly(x_test_3, 3)

#add function 

x_train_0 = add_function(x_train_0)
x_train_1 = add_function(x_train_1)
x_train_2 = add_function(x_train_2)
x_train_3 = add_function(x_train_3)

x_test_0 = add_function(x_test_0)
x_test_1 = add_function(x_test_1)
x_test_2 = add_function(x_test_2)
x_test_3 = add_function(x_test_3)

(w_0,_) = ridge_regression(y_train_0, x_train_0,1e-13)
(w_1,_) = ridge_regression(y_train_1, x_train_1,4.2389130573387746e-12)
(w_2,_) = ridge_regression(y_train_2, x_train_2,3.9372263299634755e-11)
(w_3,_) = ridge_regression(y_train_3, x_train_3,0.0001593693530381776)

y_0 = zero_to_neg(np.around(sigmoid(x_test_0 @ w_0)))
y_1 = zero_to_neg(np.around(sigmoid(x_test_1 @ w_1)))
y_2 = zero_to_neg(np.around(sigmoid(x_test_2 @ w_2)))
y_3 = zero_to_neg(np.around(sigmoid(x_test_3 @ w_3)))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-39-8954157410db> in <module>
#      28 (w_0,_) = ridge_regression(y_train_0, x_train_0,1e-13)
#      29 (w_1,_) = ridge_regression(y_train_1, x_train_1,4.2389130573387746e-12)
# ---> 30 (w_2,_) = ridge_regression(y_train_2, x_train_2,3.9372263299634755e-11)
#      31 (w_3,_) = ridge_regression(y_train_3, x_train_3,0.0001593693530381776)
#      32
#
# ~/Desktop/Machine Learning/ML/Project 1/implementations.py in ridge_regression(y, tx, lamb)
#      46     a = tx.T.dot(tx) + lamb * np.identity(tx.shape[1])
#      47     b = tx.T.dot(y)
# ---> 48     w = np.linalg.solve(a, b)
#      49     loss = MSE(y, tx, w)
#      50     return w, loss
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in solve(a, b)
#     401     signature = 'DD->D' if isComplexType(t) else 'dd->d'
# ...

# %%
y = np.concatenate((y_0,y_1,y_2,y_3))
id_test = np.concatenate((id_test_0,id_test_1,id_test_2,id_test_3))
create_csv_submission(id_test, y, 'prediction.csv')

# %%
len(x_train_0[:,1])
# Out:
# 1985

# %%
np.append(store_columns(x_train_0,4)[1], store_columns(x_train_0,4)[0], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-5c00fb325c43> in <module>
# ----> 1 np.append(store_columns(x_train_0,4)[1], store_columns(x_train_0,4)[0], axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4692         values = ravel(values)
#    4693         axis = arr.ndim-1
# -> 4694     return concatenate((arr, values), axis=axis)
#    4695
#    4696
#
# ValueError: all the input arrays must have same number of dimensions

# %%
np.concatenate((store_columns(x_train_0,4)[1],store_columns(x_train_0,4)[0]),axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-03a7ac5e31fd> in <module>
# ----> 1 np.concatenate((store_columns(x_train_0,4)[1],store_columns(x_train_0,4)[0]),axis = 0)
#
# ValueError: all the input arrays must have same number of dimensions

# %%
x_train_0
# Out:
# array([[ 0.00964144,  0.00019658,  0.00698824, ...,  0.00056868,
#         -0.00163331,  0.00557068],
#        [ 0.0017753 ,  0.0017753 ,  0.0017753 , ...,  0.0017753 ,
#          0.0017753 ,  0.0017753 ],
#        [ 0.0017753 ,  0.0017753 ,  0.0017753 , ...,  0.0017753 ,
#          0.0017753 ,  0.0017753 ],
#        ...,
#        [ 0.0017753 ,  0.0017753 ,  0.0017753 , ...,  0.0017753 ,
#          0.0017753 ,  0.0017753 ],
#        [ 0.00359991, -0.00110569,  0.00199998, ..., -0.00083918,
#         -0.00162433,  0.01190306],
#        [ 0.0017753 ,  0.0017753 ,  0.0017753 , ...,  0.0017753 ,
#          0.0017753 ,  0.0017753 ]])

# %%
store_columns(x_train_0,4)[1]
# Out:
# array([[ 0.00964144,  0.00019658,  0.00698824, ...,  0.00056868,
#         -0.00163331,  0.00557068],
#        [ 0.0017753 ,  0.0017753 ,  0.0017753 , ...,  0.0017753 ,
#          0.0017753 ,  0.0017753 ],
#        [ 0.0017753 ,  0.0017753 ,  0.0017753 , ...,  0.0017753 ,
#          0.0017753 ,  0.0017753 ],
#        ...,
#        [ 0.0017753 ,  0.0017753 ,  0.0017753 , ...,  0.0017753 ,
#          0.0017753 ,  0.0017753 ],
#        [ 0.00359991, -0.00110569,  0.00199998, ..., -0.00083918,
#         -0.00162433,  0.01190306],
#        [ 0.0017753 ,  0.0017753 ,  0.0017753 , ...,  0.0017753 ,
#          0.0017753 ,  0.0017753 ]])

# %%
store_columns(x_train_0,4)[0].reshape(1985,1)
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [0.],
#        [1.]])

# %%
np.concatenate((store_columns(x_train_0,4)[1],store_columns(x_train_0,4)[0].reshape(1985,1)),axis = 1)[:,-1]
# Out:
# array([0., 1., 1., ..., 1., 0., 1.])
